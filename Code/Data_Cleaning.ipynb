# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Json data cleaning: Scouting Reports 2019 - 2023

# %%
# Read in the scouting report data for each year
recruits_2019 = pd.read_json(r'../Data/scouting_reports_2019.json')
recruits_2020 = pd.read_json(r'../Data/scouting_reports_2020.json')
recruits_2021 = pd.read_json(r'../Data/scouting_reports_2021.json')
recruits_2022 = pd.read_json(r'../Data/scouting_reports_2022.json')
recruits_2023 = pd.read_json(r'../Data/scouting_reports_2023.json')

# %% [markdown]
# ### 2019 Data Cleaning
# ---

# %%
# Take a peek at the 2019 data
recruits_2019.head()
# Out:
#               name                                                url  rank  \
# 0  Spencer Rattler  https://247sports.com/player/spencer-rattler-8...     1
# 1   Jayden Daniels  https://247sports.com/player/jayden-daniels-89...     2
# 2           Bo Nix         https://247sports.com/player/bo-nix-77945/     3
# 3       Sam Howell     https://247sports.com/player/sam-howell-91707/     4
# 4       Max Duggan     https://247sports.com/player/max-duggan-87561/     5
#
#   position height  weight  composite_rating  \
# 0      PRO    6-1     198                99
# 1     DUAL    6-3     175                97
# 2     DUAL  6-1.5     207                96
# 3     DUAL    6-0     225                95
# 4     DUAL    6-2     190                94
#
#                           school_info            city state  ...  \
# 0              Pinnacle (Phoenix, AZ)         Phoenix    AZ  ...
# 1          Cajon (San Bernardino, CA)  San Bernardino    CA  ...
# 2          Pinson Valley (Pinson, AL)          Pinson    AL  ...
# 3             Sun Valley (Monroe, NC)          Monroe    NC  ...
# 4  Lewis Central (Council Bluffs, IA)  Council Bluffs    IA  ...
#
#   skill_delivery skill_pocket_presence skill_accuracy skill_intangibles  \
# 0           10.0                   9.0            9.0               8.0
# 1            8.0                   9.0            9.0               9.0
# 2            NaN                   NaN            NaN               NaN
# 3            8.0                   9.0            8.0               8.0
# 4            9.0                   9.0            9.0              10.0
#
#   skill_outside_the_pocket skill_mobility skill_arm_strength  skill_size  \
# 0                      8.0            8.0                8.0         6.0
# 1                      NaN            NaN                9.0         7.0
# 2                      NaN            NaN                NaN         NaN
# 3                      9.0            8.0                8.0         6.0
# 4                      NaN            NaN                8.0         8.0
#
#    skill_playmaking_ability  skill_speed
# 0                       NaN          NaN
# 1                      10.0          9.0
# 2                       NaN          NaN
# 3                       NaN          NaN
# 4                       9.0         10.0
#
# [5 rows x 29 columns]

# %% [markdown]
# Note: Specific issue with some players committed school being list as their high school instead of the college due to some of html code. Issue may be more prevlent for lower ranking players because they may not have commited anywhere out of high school, likely walk ons. Take a look at this below.

# %%
# Drop rows in the dataset where the value in the scouting report column is null
recruits_2019 = recruits_2019.dropna(subset=['scouting_report'])

# %%
recruits_2019['committed_school'].value_counts()
# Out:
# committed_school
# Penn State Nittany          2
# Oklahoma Sooners            1
# Arizona State Sun Devils    1
# Auburn Tigers               1
# North Carolina Tar Heels    1
# TCU Horned Frogs            1
# South Carolina Gamecocks    1
# Wisconsin Badgers           1
# Alabama Crimson Tide        1
# Washington Huskies          1
# Oregon Ducks                1
# Michigan Wolverines         1
# Florida Gators              1
# Tennessee Volunteers        1
# Texas A&M Aggies            1
# Clemson Tigers              1
# Oak Park                    1
# Desert Mountain             1
# Name: count, dtype: int64

# %%
recruits_2019[['name', 'committed_school']]
# Out:
#                    name          committed_school
# 0       Spencer Rattler          Oklahoma Sooners
# 1        Jayden Daniels  Arizona State Sun Devils
# 2                Bo Nix             Auburn Tigers
# 3            Sam Howell  North Carolina Tar Heels
# 4            Max Duggan          TCU Horned Frogs
# 5         Ryan Hilinski  South Carolina Gamecocks
# 6          Graham Mertz         Wisconsin Badgers
# 7     Taulia Tagovailoa      Alabama Crimson Tide
# 8          Dylan Morris        Washington Huskies
# 9           Cale Millen              Oregon Ducks
# 12        Cade McNamara       Michigan Wolverines
# 18          Jalon Jones            Florida Gators
# 21         Brian Maurer      Tennessee Volunteers
# 30     Ta'Quan Roberson        Penn State Nittany
# 31         Zach Calzada          Texas A&M Aggies
# 36   Taisun Phommachanh            Clemson Tigers
# 43         D'Wan Mathis                  Oak Park
# 44  Michael Johnson Jr.        Penn State Nittany
# 68         Kedon Slovis           Desert Mountain

# %%
df_2019 = recruits_2019[['name', 'committed_school']]

# %%
SCHOOL_MAP = {
    # FBS / major programs
    'Oklahoma Sooners':             'Oklahoma',
    'Arizona State Sun Devils':     'Arizona State',
    'Arizona State Sun':     'Arizona State',
    'Auburn Tigers':                'Auburn',
    'North Carolina Tar Heels':     'North Carolina',
    'North Carolina Tar':           'North Carolina',
    'TCU Horned Frogs':             'TCU',
    'South Carolina Gamecocks':     'South Carolina',
    'Wisconsin Badgers':            'Wisconsin',
    'Alabama Crimson Tide':         'Alabama',
    'Washington Huskies':           'Washington',
    'Oregon Ducks':                 'Oregon',
    'Arkansas Razorbacks':          'Arkansas',
    'Boise State Broncos':          'Boise State',
    'Michigan Wolverines':          'Michigan',
    'Texas Longhorns':              'Texas',
    'Ole Miss Rebels':              'Ole Miss',
    'California Golden Bears':      'California',
    'Arizona Wildcats':             'Arizona',
    'Florida Gators':               'Florida',
    'Florida State Seminoles':      'Florida State',
    'Tennessee Volunteers':         'Tennessee',
    'Oklahoma State Cowboys':       'Oklahoma State',
    'Minnesota Golden Gophers':     'Minnesota',
    'Cincinnati Bearcats':          'Cincinnati',
    'LSU Tigers':                   'LSU',
    'Notre Dame Fighting Irish':    'Notre Dame',
    'Washington State Cougars':     'Washington State',
    'Mississippi State':            'Mississippi State',
    'Toledo Rockets':               'Toledo',
    'Penn State Nittany':           'Penn State',
    'Penn State Nittany Lions':     'Penn State',
    'Texas A&M Aggies':             'Texas A&M',
    'Maryland Terrapins':           'Maryland',
    'Iowa State Cyclones':          'Iowa State',
    'Michigan State Spartans':      'Michigan State',
    'Pittsburgh Panthers':          'Pittsburgh',
    'Clemson Tigers':               'Clemson',
    'Southern Miss Golden':         'Southern Miss',
    'Southern Miss Golden Eagles':  'Southern Miss',
    'UCF Knights':                  'UCF',
    'Baylor Bears':                 'Baylor',
    'SMU Mustangs':                 'SMU',
    'Purdue Boilermakers':          'Purdue',
    'Missouri Tigers':              'Missouri',
    'Miami (OH) RedHawks':          'Miami (OH)',
    'Wake Forest Demon Deacons':    'Wake Forest',
    'BYU Cougars':                  'BYU',
    'Brigham Young Cougars':        'BYU',
    'USF Bulls':                    'USF',
    'Temple Owls':                  'Temple',
    'Miami Hurricanes':             'Miami',
    'Kent State Golden Flashes':    'Kent State',
    'Kent State Golden':            'Kent State',
    'FIU Golden Panthers':          'FIU',
    'Kentucky Wildcats':            'Kentucky',
    "Louisiana Ragin' Cajuns":      'Louisiana',
    "Louisiana Ragin'":             'Louisiana',
    'Northern Iowa Panthers':       'Northern Iowa',
    'Northern Iowa':                'Northern Iowa',
    'Georgia Tech Yellow':          'Georgia Tech',
    'Utah State Aggies':            'Utah State',
    'Nevada Wolf Pack':             'Nevada',
    'Richmond':                     'Richmond',
    'Kansas State Wildcats':        'Kansas State',
    'Texas Tech Red Raiders':       'Texas Tech',
    'Appalachian State':            'Appalachian State',
    'Boston College Eagles':        'Boston College',
    'Georgia State Panthers':       'Georgia State',
    'Memphis Tigers':               'Memphis',
    'Buffalo Bulls':                'Buffalo',
    'Syracuse Orange':              'Syracuse',
    'Old Dominion Monarchs':        'Old Dominion',
    'East Carolina Pirates':        'East Carolina',
    'Virginia Cavaliers':           'Virginia',
    'New Mexico State Aggies':      'New Mexico State',
    'Virginia Tech Hokies':         'Virginia Tech',
    'UCLA Bruins':                  'UCLA',
    'Hawaii Warriors':              'Hawaii',
    'Massachusetts Minutemen':      'Massachusetts',
    'Princeton':                    'Princeton',
    'Indiana Hoosiers':             'Indiana',
    'Ohio State Buckeyes':          'Ohio State',
    'Marshall Thundering':          'Marshall',
    'Marshall Thundering Herd':     'Marshall',
    'Central Arkansas':             'Central Arkansas',
    'UC Davis':                     'UC Davis',
    'Fresno State Bulldogs':        'Fresno State',
    'Northern Illinois':            'Northern Illinois',
    'UNLV Rebels':                  'UNLV',
    'Louisiana Tech Bulldogs':      'Louisiana Tech',
    'Rutgers Scarlet Knights':      'Rutgers',
    'Louisiana-Monroe':             'Louisiana-Monroe',
    'UAB Blazers':                  'UAB',
    'Western Michigan Broncos':     'Western Michigan',
    'Montana Grizzlies':            'Montana',
    'Eastern Kentucky':             'Eastern Kentucky',
    'Arkansas State Red Wolves':    'Arkansas State',
    'San Diego State Aztecs':       'San Diego State',
    'Utah Utes':                    'Utah',
    'North Texas Mean Green':       'North Texas',
    'Texas Southern':               'Texas Southern',
    'Louisville Cardinals':         'Louisville',
    'Akron Zips':                   'Akron',
    'Georgia Southern':             'Georgia Southern',
    'Western Carolina':             'Western Carolina',
    'Chattanooga':                  'Chattanooga',
    'Troy Trojans':                 'Troy',
    'Central Washington':           'Central Washington',
    'Air Force':                    'Air Force',
    'Mercer':                       'Mercer',
    'UTEP Miners':                  'UTEP',
    'Northern Arizona':             'Northern Arizona',
    'UTSA Roadrunners':             'UTSA',
    'USC Trojans':                  'USC',
    'Texas State Bobcats':          'Texas State',
    'Coastal Carolina':             'Coastal Carolina',
    'Harvard':                      'Harvard',
    'Central Michigan':             'Central Michigan',
    'Grand Valley State':           'Grand Valley State',
    'Houston Cougars':              'Houston',
    'Murray State':                 'Murray State',
    'Ball State Cardinals':         'Ball State',
    'Ball State':                   'Ball State',
    'Liberty Flames':               'Liberty',
    'Nicholls State Colonels':      'Nicholls State',
    'Ohio Bobcats':                 'Ohio',
    'Idaho State':                  'Idaho State',
    'San Jose State Spartans':      'San Jose State',
    'Rhode Island':                 'Rhode Island',
    'Oregon State Beavers':         'Oregon State',
    'Rice Owls':                    'Rice',
    'Eastern Michigan':             'Eastern Michigan',
    'Western Michigan':             'Western Michigan',
    'Simon Fraser':                 'Simon Fraser',
    'Navy':                         'Navy',
    'Army':                         'Army',
    'Eastern Washington':           'Eastern Washington',
    'Eastern Washington Eagles':    'Eastern Washington',
    'Western Oregon':               'Western Oregon',
    'Alabama State':                'Alabama State',
    'Kennesaw State Owls':          'Kennesaw State',
    'Texas-Permian Basin':          'Texas-Permian Basin',
    'Lamar':                        'Lamar',
    'Connecticut Huskies':          'Connecticut',
    'South Alabama Jaguars':        'South Alabama',
    'Montana State-Northern':       'Montana State-Northern',
    'Prairie View A&M':             'Prairie View A&M',
    'Tulsa Golden Hurricane':       'Tulsa',
    'Holy Cross':                   'Holy Cross',
    'Fordham':                      'Fordham',
    'Dartmouth':                    'Dartmouth',
    'Stephen F. Austin':            'Stephen F. Austin',
    'Portland State':               'Portland State',
    'Idaho':                        'Idaho',
    'Idaho Vandals':                'Idaho',
    'Georgia Bulldogs':             'Georgia',
    'Georgetown':                   'Georgetown',
    'New Hampshire':                'New Hampshire',
    'Illinois State':               'Illinois State',
    'Austin Peay':                  'Austin Peay',
    'Yale':                         'Yale',
    'East Tennessee State':         'East Tennessee State',
    'Wyoming Cowboys':              'Wyoming',
    'Vanderbilt Commodores':        'Vanderbilt',
    'Duke Blue Devils':             'Duke',
    'Georgia Tech Yellow Jackets':  'Georgia Tech',
    'Colorado Buffaloes':           'Colorado',
    'Northwestern':                 'Northwestern',
    'Northwestern Wildcats':        'Northwestern',
    'West Virginia Mountaineers':   'West Virginia',
    'West Virginia':                'West Virginia',
    'Mississippi State Bulldogs':   'Mississippi State',
    'North Dakota State Bison':     'North Dakota State',
    'Arkansas-Pine Bluff Golden':   'Arkansas-Pine Bluff',
    'Arkansas-Pine Bluff Golden Lions': 'Arkansas-Pine Bluff',
    'Tennessee State Tigers':       'Tennessee State',
    'Illinois':                     'Illinois',
    'Illinois Fighting Illini':     'Illinois',
    'Bowling Green Falcons':        'Bowling Green',
    'Pennsylvania':                 'Pennsylvania',
    'North Carolina State Wolfpack': 'North Carolina State',
    'NC State Wolfpack':            'North Carolina State',
    'Western Kentucky Hilltoppers': 'Western Kentucky',
    'Western Kentucky':             'Western Kentucky',
    'Tulane Green Wave':            'Tulane',
    'Tulane':                       'Tulane',
    'Youngstown State Penguins':    'Youngstown State',
    'Youngstown State':             'Youngstown State',
    'Eastern Michigan Eagles':      'Eastern Michigan',
    'North Dakota':                 'North Dakota',
    'Sacramento State':             'Sacramento State',
    'Davidson Wildcats':            'Davidson',
    'Davidson':                     'Davidson',
    'Buckknell':                    'Bucknell',
    'Stanford':                     'Stanford',
    'Samford':                      'Samford',
    'UC Davis Aggies':              'UC Davis',
}
 
# ── Set of known colleges (standardized names) ────────────────────────────────
# Anything NOT in this set after mapping will be flagged as non-college.
KNOWN_COLLEGES = set(SCHOOL_MAP.values())
 
# ── Apply standardization ─────────────────────────────────────────────────────
def standardize_school(raw_name):
    """Return (standardized_name, is_college) for a raw school string."""
    cleaned = raw_name.strip()
    standardized = SCHOOL_MAP.get(cleaned, cleaned)   # keep original if no mapping found
    is_college = standardized in KNOWN_COLLEGES
    return standardized, is_college
 
recruits_2019[['committed_school', 'Is_College']] = recruits_2019['committed_school'].apply(
     lambda x: pd.Series(standardize_school(x)))

# %%
recruits_2019[['name','committed_school', 'Is_College']]
# Out:
#                 name    committed_school  Is_College
# 0    Spencer Rattler            Oklahoma        True
# 1     Jayden Daniels       Arizona State        True
# 2             Bo Nix              Auburn        True
# 3         Sam Howell      North Carolina        True
# 4         Max Duggan                 TCU        True
# ..               ...                 ...         ...
# 242   Heath Williams           Northeast       False
# 243      Nick Lasher               Norco       False
# 244   Mitch McKenzie  Archbishop Moeller       False
# 245       Jack Baltz      Illinois State        True
# 246   Bryce Robinson         Austin Peay        True
#
# [247 rows x 3 columns]

# %% [markdown]
# Search 247 to see which are the actual colleges of players with colleges not in college list.
#
# 19 = N.C State
# 43 = Georgia
# 68 = USC
# 71 = NA
# 86 = NA
# 103 = NA
# 115 = NA
# 128 = NA
# 130 = NA
# 139 = NA
# 149 = NA
# 150 = NA
# 157 = NA
# 158 = NA
# 167 = NA
# 170 = NA
# 172 = NA
# 177 = NA
# 179 = NA
# 183 = NA
# 186 = NA
# 189 = NA
# 194 = NA
# 196 = NA
# 197 = NA
# 198 = NA
# 203 = NA
# 205 = NA
# 206 = NA
# 208 = NA
# 210 = NA
# 214 = NA
# 215 = NA
# 222 = NA
# 224 = NA
# 228 = NA
# 229 = NA
# 232 = NA
# 233 = NA
# 234 = NA
# 237 = NA
# 238 = NA
# 242 = NA
# 243 = NA
# 244 = NA
#
#
# As seen above, looks like most of these are simply players that did not get a landing spot out of high school. The first few misses are likely due to the '.' in 'N.C. State' and some html formatting. More specifically, I believe that these players have long recruiting timelines, which may affect the ability of the scrapper to pick them up.

# %%
# Replace non-college entries with NaN
recruits_2019.loc[~recruits_2019['Is_College'], 'committed_school'] = np.nan

# Replace row 19 with N.C State
recruits_2019.loc[19, 'committed_school'] = 'North Carolina State'
recruits_2019.loc[19, 'Is_College'] = True

# Replace row 43 with Georgia
recruits_2019.loc[43, 'committed_school'] = 'Georgia'
recruits_2019.loc[43, 'Is_College'] = True

# Replace row 68 with USC
recruits_2019.loc[68, 'committed_school'] = 'USC'
recruits_2019.loc[68, 'Is_College'] = True

# %%
# Check the results
recruits_2019[['name','committed_school', 'Is_College']]
# Out:
#                 name committed_school  Is_College
# 0    Spencer Rattler         Oklahoma        True
# 1     Jayden Daniels    Arizona State        True
# 2             Bo Nix           Auburn        True
# 3         Sam Howell   North Carolina        True
# 4         Max Duggan              TCU        True
# ..               ...              ...         ...
# 242   Heath Williams              NaN       False
# 243      Nick Lasher              NaN       False
# 244   Mitch McKenzie              NaN       False
# 245       Jack Baltz   Illinois State        True
# 246   Bryce Robinson      Austin Peay        True
#
# [247 rows x 3 columns]

# %% [markdown]
# ## 2020 recruits

# %%
# Look at the 2020 data
recruits_2020
# Out:
#                    name                                                url  \
# 0           Bryce Young    https://247sports.com/player/bryce-young-93127/
# 1         DJ Uiagalelei  https://247sports.com/player/dj-uiagalelei-455...
# 2           C.J. Stroud   https://247sports.com/player/cj-stroud-46038118/
# 3           Evan Prater  https://247sports.com/player/evan-prater-46050...
# 4    Ja'Quinden Jackson  https://247sports.com/player/jaquinden-jackson...
# ..                  ...                                                ...
# 242         Colt Minson  https://247sports.com/player/colt-minson-46080...
# 243          Jake Byrne  https://247sports.com/player/jake-byrne-46080937/
# 244         Jack Jancek  https://247sports.com/player/jack-jancek-46085...
# 245        Asher Morgan  https://247sports.com/player/asher-morgan-4608...
# 246       Nathan Thomas  https://247sports.com/player/nathan-thomas-460...
#
#      rank position height  weight  composite_rating  \
# 0       1     DUAL   5-11     183               101
# 1       2      PRO  6-4.5     246               101
# 2       3      PRO  6-2.5     194                98
# 3       4     DUAL    6-5     190                97
# 4       5     DUAL    6-2     219                97
# ..    ...      ...    ...     ...               ...
# 242   245      PRO   5-11     200                77
# 243   246     DUAL    6-0     175                76
# 244   247     DUAL    6-5     185                76
# 245   248      PRO  6-3.5     212                76
# 246   249      PRO    6-3     175                76
#
#                                  school_info              city state  ...  \
# 0                  Mater Dei (Santa Ana, CA)         Santa Ana    CA  ...
# 1            St. John Bosco (Bellflower, CA)        Bellflower    CA  ...
# 2    Rancho Cucamonga (Rancho Cucamonga, CA)  Rancho Cucamonga    CA  ...
# 3                   Wyoming (Cincinnati, OH)        Cincinnati    OH  ...
# 4              Duncanville (Duncanville, TX)       Duncanville    TX  ...
# ..                                       ...               ...   ...  ...
# 242            Catholic (Virginia Beach, VA)    Virginia Beach    VA  ...
# 243                     Freedom (Oakley, CA)            Oakley    CA  ...
# 244       Knoxville Catholic (Knoxville, TN)         Knoxville    TN  ...
# 245          Philadelphia (Philadelphia, MS)      Philadelphia    MS  ...
# 246             Graham-Kapowsin (Graham, WA)            Graham    WA  ...
#
#     skill_leadership skill_scorer/finisher skill_passing/vision  \
# 0                NaN                   NaN                  NaN
# 1                NaN                   NaN                  NaN
# 2                NaN                   NaN                  NaN
# 3                NaN                   NaN                  NaN
# 4                NaN                   NaN                  NaN
# ..               ...                   ...                  ...
# 242              NaN                   NaN                  NaN
# 243              NaN                   NaN                  NaN
# 244              NaN                   NaN                  NaN
# 245              NaN                   NaN                  NaN
# 246              NaN                   NaN                  NaN
#
#     skill_defender skill_passing skill_penetration_ability skill_athleticism  \
# 0              NaN           NaN                       NaN               NaN
# 1              NaN           NaN                       NaN               NaN
# 2              NaN           NaN                       NaN               NaN
# 3              NaN           NaN                       NaN               NaN
# 4              NaN           NaN                       NaN               NaN
# ..             ...           ...                       ...               ...
# 242            NaN           NaN                       NaN               NaN
# 243            NaN           NaN                       NaN               NaN
# 244            NaN           NaN                       NaN               NaN
# 245            NaN           NaN                       NaN               NaN
# 246            NaN           NaN                       NaN               NaN
#
#      skill_handle  skill_shooter  skill_rebounding
# 0             NaN            NaN               NaN
# 1             NaN            NaN               NaN
# 2             NaN            NaN               NaN
# 3             NaN            NaN               NaN
# 4             NaN            NaN               NaN
# ..            ...            ...               ...
# 242           NaN            NaN               NaN
# 243           NaN            NaN               NaN
# 244           NaN            NaN               NaN
# 245           NaN            NaN               NaN
# 246           NaN            NaN               NaN
#
# [247 rows x 39 columns]

# %% [markdown]
# NOTE: Looks like for whatever reason, certain players had basketball attirbutes. This is likely due to certain players being dual sport athletes in high school.
#
# Regardless, let's drop these columns before repeating the same process as in the 2019 dataset.

# %%
recruits_2019.columns
# Out:
# Index(['name', 'url', 'rank', 'position', 'height', 'weight',
#        'composite_rating', 'school_info', 'city', 'state', 'scouting_report',
#        'draft_projection', 'reminds_of', 'evaluated_date', 'analyst',
#        'athletic_background', 'committed_school', 'numerical_rating', 'stars',
#        'skill_delivery', 'skill_pocket_presence', 'skill_accuracy',
#        'skill_intangibles', 'skill_outside_the_pocket', 'skill_mobility',
#        'skill_arm_strength', 'skill_size', 'skill_playmaking_ability',
#        'skill_speed', 'Is_College'],
#       dtype='str')

# %%
# Look at the columns
recruits_2020.columns
# Out:
# Index(['name', 'url', 'rank', 'position', 'height', 'weight',
#        'composite_rating', 'school_info', 'city', 'state', 'scouting_report',
#        'draft_projection', 'reminds_of', 'evaluated_date', 'analyst',
#        'athletic_background', 'committed_school', 'numerical_rating', 'stars',
#        'skill_intangibles', 'skill_playmaking_ability',
#        'skill_pocket_presence', 'skill_delivery', 'skill_accuracy',
#        'skill_arm_strength', 'skill_speed', 'skill_size',
#        'skill_outside_the_pocket', 'skill_mobility', 'skill_leadership',
#        'skill_scorer/finisher', 'skill_passing/vision', 'skill_defender',
#        'skill_passing', 'skill_penetration_ability', 'skill_athleticism',
#        'skill_handle', 'skill_shooter', 'skill_rebounding'],
#       dtype='str')

# %%
# Drop the irrelevant columns
recruits_2020 = recruits_2020.drop(columns=['skill_leadership',
       'skill_scorer/finisher', 'skill_passing/vision', 'skill_defender',
       'skill_passing', 'skill_penetration_ability', 'skill_athleticism',
       'skill_handle', 'skill_shooter', 'skill_rebounding'])

# %% [markdown]
# Now we will fix college names

# %%
recruits_2020[['name','committed_school', 'Is_College', 'scouting_report']]
# Out:
#                    name committed_school  Is_College  \
# 0           Bryce Young        Mater Dei       False
# 1         DJ Uiagalelei          Clemson        True
# 2           C.J. Stroud       Ohio State        True
# 3           Evan Prater       Cincinnati        True
# 4    Ja'Quinden Jackson            Texas        True
# ..                  ...              ...         ...
# 242         Colt Minson  Charlotte 49ers       False
# 243          Jake Byrne          Freedom       False
# 244         Jack Jancek        Tennessee        True
# 245        Asher Morgan          Samford       False
# 246       Nathan Thomas  Graham-Kapowsin       False
#
#                                        scouting_report
# 0    Has a slight frame and needs to bulk up and ad...
# 1    Big, strong armed quarterback with generationa...
# 2    Stroud has a solid frame and will have no prob...
# 3    Tall with a big frame. Plays basketball during...
# 4    Powerfully built, athletic, rocked up athlete....
# ..                                                 ...
# 242                                                NaN
# 243                                                NaN
# 244                                                NaN
# 245                                                NaN
# 246                                                NaN
#
# [247 rows x 4 columns]

# %%
# Apply function from earlier to standardize the committed_school column and create Is_College flag
recruits_2020[['committed_school', 'Is_College']] = recruits_2020['committed_school'].apply(
     lambda x: pd.Series(standardize_school(x)))

# %%
# Take a look at the results
recruits_2020[['name','committed_school', 'Is_College']]
# Out:
#                    name committed_school  Is_College
# 0           Bryce Young        Mater Dei       False
# 1         DJ Uiagalelei          Clemson        True
# 2           C.J. Stroud       Ohio State        True
# 3           Evan Prater       Cincinnati        True
# 4    Ja'Quinden Jackson            Texas        True
# ..                  ...              ...         ...
# 242         Colt Minson  Charlotte 49ers       False
# 243          Jake Byrne          Freedom       False
# 244         Jack Jancek        Tennessee        True
# 245        Asher Morgan          Samford       False
# 246       Nathan Thomas  Graham-Kapowsin       False
#
# [247 rows x 3 columns]

# %% [markdown]
# Stopped on page 10
#
# Notes:
#
# 0 = Alabama
#
# chandler galban, Gunnar Gray and Derohn King should be blank
