# %% [markdown]
# In this notebbook, Data is aggregated from cfb-reference.com in order to get team stats.
#
# Ultimate goal:
#
# - Build 2 datasets: team stats and team standings

# %%
import pandas as pd
import numpy as np
import requests
from io import StringIO

# %% [markdown]
# ## Team stats
# ---
